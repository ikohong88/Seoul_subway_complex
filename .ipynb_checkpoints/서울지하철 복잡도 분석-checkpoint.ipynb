# %% [markdown]
# # 서울지하철 복잡도 분석
# ## 데이터 설명
# - 데이터 :
#     - https://www.data.go.kr/tcs/dss/selectFileDataDetailView.do?publicDataPk=15071311 [공공데이터포털 - 서울교통공사_지하철혼잡도정보]
#
# - 데이터 설명 :
#     - 서울교통공사 1-8호선 30분 단위 평균 혼잡도로 30분간 지나는 열차들의 평균 혼잡도(정원대비 승차인원으로, 승차인과 좌석수가 일치할 경우를 혼잡도 34%로 산정) 입니다.(단위: %). 서울교통공사 혼잡도 데이터는 조사일자(평일, 토요일, 일요일), 호선, 역번호, 역명, 상하선구분, 30분단위 별 혼잡도 데이터로 구성되어 있습니다. (2년 단위 업데이트 자료 입니다.)
#
# ## 프로젝트 기획 및 배경
# - 서울 대한민국의 인구밀도는 1km 제곱당 15,699명이 살고 있음을 통계를 통해 확인할 수 있다. <br>
# (참고 : https://www.index.go.kr/potal/main/EachDtlPageDetail.do?idx_cd=1007: 지역별 인구 및 인구밀도 [2021년 기준]) <br>
# 서울의 인구밀도가 높다보니, 인구들이 이동하기 위한 교통수단의 밀집도도 상당할것으로 예상을 한다. 따라서 서울지하철의 복잡도 데이터를 통해 역별,구분별,요일별,호선별,시간별 복잡도를 분석해보고, 출근시간인 '8시30분'의 데이터를 추측하기 위한 모델 훈련을 시도해본다.
#
# ## 프로젝트 내용
#
# 1. 개발환경
#     - jupyter notebook을 통해 프로젝트 진행
# 2. 데이터 불러오기
#     - '공공데이터포털 - 서울교통공사_지하철혼잡도정보' csv 파일을 활용하였습니다.
# 3. 데이터 정제 & 시각화
#     1. 역별 데이터 정제 & 시각화
#     2. 구분별 데이터 정제 & 시각화
#     3. 요일별 데이터 정제 & 시각화
#     4. 호선별 데이터 정제 & 시각화
# 4. '8시30분'과 상관관계 확인
# 5. 데이터 전처리
# 6. 학습
# 7. 발전 가능성

# %% [markdown]
# ## 1. 환경설정

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split

from tensorflow.keras.layers import Input, Dense, BatchNormalization
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam

from matplotlib import font_manager, rc

# jupyter notebook에서 한글 깨짐 현상으로 한글폰트 적용
rc('font', family='Malgun Gothic')

# %% [markdown]
# ## 2. 데이터 불러오기

# %%
# pandas를 사용하여 dataframe 형태로 불러옵니다.
data = pd.read_csv("D:/github/서울지하철 복잡도/서울교통공사_지하철혼잡도정보_20211231.csv", encoding='CP949')

# %%
# 데이터가 정상적으로 출력되는지 확인하기 위해 상위 5개의 데이터 샘플을 출력
data.head()
# Out:
#    연번 조사일자  호선  역번호   역명  구분  5시30분  6시00분  6시30분  7시00분  ...  19시00분  19시30분  \
# 0   1   평일   1  150  서울역  상선    6.2   14.6   13.4   26.8  ...    20.0    15.1
# 1   2   평일   1  150  서울역  하선    9.1    8.6    9.3   15.2  ...    37.5    26.5
# 2   3   평일   1  151   시청  상선    5.4   10.1   13.0   20.8  ...    24.1    17.4
# 3   4   평일   1  151   시청  하선    7.0    6.8   10.2   14.5  ...    33.8    22.9
# 4   5   평일   1  152   종각  상선    5.2   10.8    9.3   13.6  ...    28.8    20.2
#
#    20시00분  20시30분  21시00분  21시30분  22시00분  22시30분  23시00분  23시30분
# 0    11.1    12.0    12.5    10.1    10.4    16.4     7.8     6.1
# 1    25.5    26.4    26.3    21.1    32.1    20.3    12.6    10.3
# 2    13.7    14.5    15.8    12.1    14.5    18.3    11.7    11.7
# 3    22.0    24.1    23.0    21.0    24.8    18.5    11.8     9.1
# 4    19.1    18.7    22.2    16.1    21.8    25.1    16.3    14.8
#
# [5 rows x 43 columns]

# %%
# dataframe의 정보를 요약해서 출력 - 해당 데이터는 결측값이 없는것으로 확인
data.info()
# 데이터 모양 확인
data.shape
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1704 entries, 0 to 1703
# Data columns (total 43 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   연번      1704 non-null   int64
#  1   조사일자    1704 non-null   object
#  2   호선      1704 non-null   int64
#  3   역번호     1704 non-null   int64
#  4   역명      1704 non-null   object
#  5   구분      1704 non-null   object
#  6   5시30분   1704 non-null   float64
#  7   6시00분   1704 non-null   float64
#  8   6시30분   1704 non-null   float64
#  9   7시00분   1704 non-null   float64
#  10  7시30분   1704 non-null   float64
#  11  8시00분   1704 non-null   float64
#  12  8시30분   1704 non-null   float64
#  13  9시00분   1704 non-null   float64
#  14  9시30분   1704 non-null   float64
#  15  10시00분  1704 non-null   float64
#  16  10시30분  1704 non-null   float64
#  17  11시00분  1704 non-null   float64
#  18  11시30분  1704 non-null   float64
#  19  12시00분  1704 non-null   float64
#  20  12시30분  1704 non-null   float64
# ...

# %%
# describe를 통해 수치형 변수의 데이터 정보를 요약하여 출력합니다.
# mean은 평균, std는 표준편차를 나타냅니다. 
# 해당 요약 정보는 지하철 전체 시간별 요약 정보입니다.
data.describe()
# Out:
#                 연번           호선          역번호        5시30분        6시00분  \
# count  1704.000000  1704.000000  1704.000000  1704.000000  1704.000000
# mean    852.500000     5.235915  1645.390845    12.829049    12.454460
# std     492.046746     2.889140  1171.787868    11.507665     8.893017
# min       1.000000     1.000000   150.000000     0.000000     0.000000
# 25%     426.750000     3.000000   318.750000     5.600000     6.500000
# 50%     852.500000     5.000000  2531.500000     9.700000    10.300000
# 75%    1278.250000     7.000000  2646.250000    16.500000    16.100000
# max    1704.000000    15.000000  2827.000000    89.000000    56.500000
#
#              6시30분        7시00분        7시30분        8시00분        8시30분  ...  \
# count  1704.000000  1704.000000  1704.000000  1704.000000  1704.000000  ...
# mean     12.589847    15.340728    19.757512    27.309096    24.065669  ...
# std      10.275193    14.774740    19.332359    26.940089    22.153565  ...
# ...

# %% [markdown]
# 문득 출근시간인 '8시00분'를 기준으로 어떤역이 가장 복잡도가 높은지 확인을 해보고 싶었다.
# 그래서 아래의 코드를 통해 해당 데이터를 확인할 수 있었다.

# %%
# 모든 컬럼의 확인을 위해 옵션 설정
pd.set_option('display.max_columns',None)
# 데이터 중 출근시간인 8시에 어떤 역에서 복잡도가 가장 높은지 확인
data[['8시00분','역명','구분','호선','조사일자']].sort_values(by='8시00분', ascending=False).head(10)
# Out:
#      8시00분      역명  구분  호선 조사일자
# 211  150.8   한성대입구  하선   4   평일
# 209  150.6  성신여대입구  하선   4   평일
# 213  141.6      혜화  하선   4   평일
# 207  140.6      길음  하선   4   평일
# 135  140.6     무악재  하선   3   평일
# 133  138.9      홍제  하선   3   평일
# 137  137.5     독립문  하선   3   평일
# 71   135.6      사당  외선   2   평일
# 539  134.1    강동구청  하선   8   평일
# 205  133.7   미아삼거리  하선   4   평일

# %% [markdown]
# 위의 데이터를 통해 '평일 - 4호선 - 한성대입구 - 하선'에서 150.8%로 가장 복잡한것을 확인할 수 있었다.

# %% [markdown]
# ## 3. 데이터 정제 & 시각화

# %%
# 필요 없는 변수 '역번호','연번' 제거
data_clean = data.drop(columns = ['역번호', '연번'], axis = 1).copy()

# %%
# 5개의 데이터 샘플을 출력합니다.
data_clean.head()
# Out:
#   조사일자  호선   역명  구분  5시30분  6시00분  6시30분  7시00분  7시30분  8시00분  ...  19시00분  \
# 0   평일   1  서울역  상선    6.2   14.6   13.4   26.8   43.3   53.6  ...    20.0
# 1   평일   1  서울역  하선    9.1    8.6    9.3   15.2   29.3   27.7  ...    37.5
# 2   평일   1   시청  상선    5.4   10.1   13.0   20.8   32.0   40.6  ...    24.1
# 3   평일   1   시청  하선    7.0    6.8   10.2   14.5   27.0   24.7  ...    33.8
# 4   평일   1   종각  상선    5.2   10.8    9.3   13.6   19.6   25.5  ...    28.8
#
#    19시30분  20시00분  20시30분  21시00분  21시30분  22시00분  22시30분  23시00분  23시30분
# 0    15.1    11.1    12.0    12.5    10.1    10.4    16.4     7.8     6.1
# 1    26.5    25.5    26.4    26.3    21.1    32.1    20.3    12.6    10.3
# 2    17.4    13.7    14.5    15.8    12.1    14.5    18.3    11.7    11.7
# 3    22.9    22.0    24.1    23.0    21.0    24.8    18.5    11.8     9.1
# 4    20.2    19.1    18.7    22.2    16.1    21.8    25.1    16.3    14.8
#
# [5 rows x 41 columns]

# %% [markdown]
# ### 3-1. 역명별 데이터 분석
# - 호선, 시간, 조사일자, 구분 상관없이, 데이터 전체 역명별 복잡도 확인

# %%
# 필요없는 컬럼 '조사일자','호선',구분' 제거
data_station_name = data_clean.drop(columns = ['조사일자','호선','구분'], axis = 1).copy()
data_station_name.head()
# Out:
#     역명  5시30분  6시00분  6시30분  7시00분  7시30분  8시00분  8시30분  9시00분  9시30분  ...  \
# 0  서울역    6.2   14.6   13.4   26.8   43.3   53.6   70.9   40.4   38.0  ...
# 1  서울역    9.1    8.6    9.3   15.2   29.3   27.7   19.0   18.5   15.1  ...
# 2   시청    5.4   10.1   13.0   20.8   32.0   40.6   50.9   30.8   35.8  ...
# 3   시청    7.0    6.8   10.2   14.5   27.0   24.7   20.0   18.4   14.5  ...
# 4   종각    5.2   10.8    9.3   13.6   19.6   25.5   26.5   19.2   26.2  ...
#
#    19시00분  19시30분  20시00분  20시30분  21시00분  21시30분  22시00분  22시30분  23시00분  \
# 0    20.0    15.1    11.1    12.0    12.5    10.1    10.4    16.4     7.8
# 1    37.5    26.5    25.5    26.4    26.3    21.1    32.1    20.3    12.6
# 2    24.1    17.4    13.7    14.5    15.8    12.1    14.5    18.3    11.7
# 3    33.8    22.9    22.0    24.1    23.0    21.0    24.8    18.5    11.8
# 4    28.8    20.2    19.1    18.7    22.2    16.1    21.8    25.1    16.3
#
#    23시30분
# 0     6.1
# 1    10.3
# 2    11.7
# 3     9.1
# 4    14.8
# ...

# %%
# 행,열 위치를 바꾸기 전 인덱스를'역명'으로 변경후 위치를 변경한다.
# 인덱스를 '역명'으로 변경
data_station_name = data_station_name.set_index("역명")
data_station_name.head()
# Out:
#      5시30분  6시00분  6시30분  7시00분  7시30분  8시00분  8시30분  9시00분  9시30분  10시00분  \
# 역명
# 서울역    6.2   14.6   13.4   26.8   43.3   53.6   70.9   40.4   38.0    26.6
# 서울역    9.1    8.6    9.3   15.2   29.3   27.7   19.0   18.5   15.1    13.9
# 시청     5.4   10.1   13.0   20.8   32.0   40.6   50.9   30.8   35.8    20.2
# 시청     7.0    6.8   10.2   14.5   27.0   24.7   20.0   18.4   14.5    13.5
# 종각     5.2   10.8    9.3   13.6   19.6   25.5   26.5   19.2   26.2    17.0
#
#      ...  19시00분  19시30분  20시00분  20시30분  21시00분  21시30분  22시00분  22시30분  \
# 역명   ...
# 서울역  ...    20.0    15.1    11.1    12.0    12.5    10.1    10.4    16.4
# 서울역  ...    37.5    26.5    25.5    26.4    26.3    21.1    32.1    20.3
# 시청   ...    24.1    17.4    13.7    14.5    15.8    12.1    14.5    18.3
# 시청   ...    33.8    22.9    22.0    24.1    23.0    21.0    24.8    18.5
# 종각   ...    28.8    20.2    19.1    18.7    22.2    16.1    21.8    25.1
#
#      23시00분  23시30분
# 역명
# 서울역     7.8     6.1
# ...

# %%
# 필요없는 컬럼을 제거하고 역명을 보면 같은 이름의 역명이 2개씩 있는것이 확인이 된다.
# 이는 상선, 하선, 내선, 외선으로 구분이 되어있기에 같은 역명의 데이터를 합친다.
# 새로운 데이터프레임을 생성
new_data_station = pd.DataFrame()

# %% [markdown]
# 데이터 전처리를 한 다음 확인을 해보니, 환승역이 있기 때문에 '구분'을 기준으로만 데이터를 전처리 하면 안되는것을 파악하였다.
# ![image.png](attachment:image.png)

# %%
# 인덱스 길이
index_len = len(data_station_name.index)

station_name = set([])

# 역명 추출
for i in range(index_len):
    station_name.add(data_station_name['역명'][i])

# 역명별 평균값을 새로 생성한 데이터프레임에 추가
for j in station_name:
    station_len = len(data_station_name[data_station_name['역명']==j])
    select_data = data_station_name[data_station_name['역명']==j]
    new_data_seri = select_data.mean()
    new_data_station = new_data_station.append(new_data_seri, ignore_index=True)

# %%
# 역명'컬럼 추가
new_data_station['역명']=list(station_name)
# 인덱스명을 '역명'컬럼으로 변경
new_data_station = new_data_station.set_index('역명')

# %%
# 새로 생성한 데이터프레임 확인
new_data_station.head()
# Out:
#             5시30분      6시00분      6시30분      7시00분      7시30분      8시00분  \
# 역명
# 낙성대     30.350000  21.416667  24.366667  27.733333  31.316667  47.850000
# 까치울     22.416667  15.983333  16.883333  21.966667  30.500000  39.916667
# 애오개      8.416667   9.400000  10.433333  15.516667  19.916667  25.600000
# 월드컵경기장  10.850000  11.183333   9.716667  14.950000  18.850000  27.100000
# 천호      12.208333  15.566667  16.175000  17.225000  23.608333  32.891667
#
#             8시30분      9시00분      9시30분     10시00분  ...     19시00분     19시30분  \
# 역명                                                  ...
# 낙성대     45.566667  44.066667  41.800000  35.450000  ...  42.016667  33.750000
# 까치울     34.150000  36.333333  30.466667  27.683333  ...  35.700000  29.283333
# 애오개     24.783333  21.783333  20.933333  18.000000  ...  23.216667  19.566667
# 월드컵경기장  21.650000  20.983333  20.150000  19.400000  ...  25.683333  20.250000
# ...

# %%
# 서울역 출퇴근길 데이터 (전처리 후)
new_data_station.loc['서울역','7시30분':'9시30분'].to_frame()
# Out:
#              서울역
# 7시30분  15.133333
# 8시00분  21.725000
# 8시30분  22.900000
# 9시00분  20.566667
# 9시30분  21.483333

# %%
# 서울역 출퇴근길 데이터 (전처리 전)
data.loc[data['역명'] == '서울역' ,['역명','호선','조사일자','구분','7시30분','8시00분','8시30분','9시00분','9시30분']]
# Out:
#        역명  호선 조사일자  구분  7시30분  8시00분  8시30분  9시00분  9시30분
# 0     서울역   1   평일  상선   43.3   53.6   70.9   40.4   38.0
# 1     서울역   1   평일  하선   29.3   27.7   19.0   18.5   15.1
# 224   서울역   4   평일  상선   25.3   43.0   47.4   35.2   33.2
# 225   서울역   4   평일  하선   17.5   23.8   24.9   16.3   17.9
# 568   서울역   1  토요일  상선   10.0   20.4   19.3   21.0   25.9
# 569   서울역   1  토요일  하선    7.6   11.7   11.1   14.8   15.1
# 792   서울역   4  토요일  상선   14.1   23.7   24.4   28.9   28.8
# 793   서울역   4  토요일  하선    9.9   11.4   14.0   16.2   18.1
# 1136  서울역   1  일요일  상선    7.5   14.1   12.8   14.6   18.9
# 1137  서울역   1  일요일  하선    4.5    7.9    7.2   10.5   11.5
# 1360  서울역   4  일요일  상선    7.2   15.1   15.1   18.6   21.0
# 1361  서울역   4  일요일  하선    5.4    8.3    8.7   11.8   14.3

# %% [markdown]
# 데이터를 보게되면, 원본데이터의 지하철 밀집도(%)가 조건에 따라 확연한 차이를 보이고 있었다.평균 데이터상에서는 좌석에 앉을수 있을정도로 혼잡도가 낮게 나와있지만, '서울역 - 1호선 - 평일 - 상선 - 8시30분'데이터를 보면 '70.9%'로 혼잡도가 높게 나와있는 모습을 볼 수 있습니다..

# %% [markdown]
# ### 3-1-1. 역명별 시각화 (1호선 기준)
# - 역명이 너무 많아 1호선 기준으로 역명별 데이터를 시각화 하였습니다.
# - 1호선 기준으로 하기에 전처리를 다시 진행하였습니다.

# %%
data_train_num_1 = data[(data['호선'] == 1)].copy()
data_train_num_1.head(3)
# Out:
#    연번 조사일자  호선  역번호   역명  구분  5시30분  6시00분  6시30분  7시00분  ...  19시00분  19시30분  \
# 0   1   평일   1  150  서울역  상선    6.2   14.6   13.4   26.8  ...    20.0    15.1
# 1   2   평일   1  150  서울역  하선    9.1    8.6    9.3   15.2  ...    37.5    26.5
# 2   3   평일   1  151   시청  상선    5.4   10.1   13.0   20.8  ...    24.1    17.4
#
#    20시00분  20시30분  21시00분  21시30분  22시00분  22시30분  23시00분  23시30분
# 0    11.1    12.0    12.5    10.1    10.4    16.4     7.8     6.1
# 1    25.5    26.4    26.3    21.1    32.1    20.3    12.6    10.3
# 2    13.7    14.5    15.8    12.1    14.5    18.3    11.7    11.7
#
# [3 rows x 43 columns]

# %%
data_train_num_1 = data_train_num_1.drop(columns = ['조사일자','역번호','연번','호선','구분'])
# 새로운 데이터프레임 생성을 위해 인덱스 초기화 필요
data_train_num_1 = data_train_num_1.reset_index(drop=True)

# %%
data_train_num_1.head()
# Out:
#     역명  5시30분  6시00분  6시30분  7시00분  7시30분  8시00분  8시30분  9시00분  9시30분  ...  \
# 0  서울역    6.2   14.6   13.4   26.8   43.3   53.6   70.9   40.4   38.0  ...
# 1  서울역    9.1    8.6    9.3   15.2   29.3   27.7   19.0   18.5   15.1  ...
# 2   시청    5.4   10.1   13.0   20.8   32.0   40.6   50.9   30.8   35.8  ...
# 3   시청    7.0    6.8   10.2   14.5   27.0   24.7   20.0   18.4   14.5  ...
# 4   종각    5.2   10.8    9.3   13.6   19.6   25.5   26.5   19.2   26.2  ...
#
#    19시00분  19시30분  20시00분  20시30분  21시00분  21시30분  22시00분  22시30분  23시00분  \
# 0    20.0    15.1    11.1    12.0    12.5    10.1    10.4    16.4     7.8
# 1    37.5    26.5    25.5    26.4    26.3    21.1    32.1    20.3    12.6
# 2    24.1    17.4    13.7    14.5    15.8    12.1    14.5    18.3    11.7
# 3    33.8    22.9    22.0    24.1    23.0    21.0    24.8    18.5    11.8
# 4    28.8    20.2    19.1    18.7    22.2    16.1    21.8    25.1    16.3
#
#    23시30분
# 0     6.1
# 1    10.3
# 2    11.7
# 3     9.1
# 4    14.8
# ...

# %%
# 필요없는 컬럼을 제거하고 역명을 보면 같은 이름의 역명이 여러개 있는것이 확인이 된다.
# 이는 상선, 하선, 내선, 외선으로 구분이 되어있기에 같은 역명의 데이터를 합친다.
# 새로운 데이터프레임을 생성
new_data_train_1 = pd.DataFrame()

# %%
# 인덱스 길이
index_len = len(data_train_num_1.index)

train_1 = set([])

# 역명 추출
for i in range(index_len):
    train_1.add(data_train_num_1['역명'][i])

# 역명별 평균값을 새로 생성한 데이터프레임에 추가
for j in train_1:
    select_data = data_train_num_1[data_train_num_1['역명']==j]
    new_data_seri = select_data.mean()
    new_data_train_1 = new_data_train_1.append(new_data_seri, ignore_index=True)

# %%
new_data_train_1.head(3)
# Out:
#       5시30분     6시00분     6시30분      7시00분      7시30분      8시00분      8시30분  \
# 0  8.866667  9.533333  8.433333  11.300000  14.716667  20.983333  18.483333
# 1  6.000000  8.150000  7.850000   9.733333  13.516667  17.616667  17.600000
# 2  5.800000  7.766667  8.500000  10.283333  15.133333  18.300000  19.783333
#
#    9시00분      9시30분     10시00분  ...     19시00분     19시30분     20시00분  \
# 0  17.75  17.883333  17.866667  ...  16.466667  12.866667  14.916667
# 1  16.45  18.766667  17.650000  ...  20.683333  18.100000  17.700000
# 2  17.35  20.616667  18.016667  ...  22.316667  18.000000  17.983333
#
#       20시30분     21시00분     21시30분     22시00분     22시30분     23시00분    23시30분
# 0  10.500000  13.100000  11.583333  12.116667  12.233333   9.183333  7.616667
# 1  15.533333  18.183333  15.866667  16.716667  14.550000  11.416667  9.333333
# 2  15.833333  17.416667  15.700000  15.683333  13.683333   9.883333  9.050000
#
# [3 rows x 37 columns]

# %%
# 데이터 시각화
# seaborn 한글 깨짐 현상으로 폰트 적용
plt.rcParams['font.family'] = 'Malgun Gothic'

plt.rcParams["figure.figsize"] = (16,8)

# 행,열 위치 변경 후 시각화 진행
plot = new_data_train_1.T.plot()
plot.set_xlabel("시간")
plot.set_ylabel("복잡도")
plt.title("역명별 복잡도[1호선 기준]")

# 오른쪽 상단 범례 표시
plt.legend(['동대문', '동묘앞', '서울역', '시청', '신설동', '제기동', '종각', '종로3가', '종로5가', '청량리'], loc='upper right')
plt.show()

# %%
# 0 - '동대문',1 - '동묘앞',2 - '서울역',3 - '시청',4 - '신설동',5 - '제기동',6 - '종각',7 - '종로3가',8 - '종로5가',9 - '청량리'
# seaborn의 pairplot()을 사용해서 컬럼끼리 비교
# 컬럼 비교를 위해 행,열 위치 변경 후 시각화 진행
sns.pairplot(new_data_train_1.T)

# %% [markdown]
# ### 3-2. 구분별 데이터 분석
# - 상선, 하선, 내선, 외선별 복잡도 분석

# %%
# 필요없는 컬럼 '조사일자','호선','역명' 제거
data_station_division = data_clean.drop(columns = ['조사일자','호선','역명'], axis = 1).copy()
data_station_division.head()
# Out:
#    구분  5시30분  6시00분  6시30분  7시00분  7시30분  8시00분  8시30분  9시00분  9시30분  ...  \
# 0  상선    6.2   14.6   13.4   26.8   43.3   53.6   70.9   40.4   38.0  ...
# 1  하선    9.1    8.6    9.3   15.2   29.3   27.7   19.0   18.5   15.1  ...
# 2  상선    5.4   10.1   13.0   20.8   32.0   40.6   50.9   30.8   35.8  ...
# 3  하선    7.0    6.8   10.2   14.5   27.0   24.7   20.0   18.4   14.5  ...
# 4  상선    5.2   10.8    9.3   13.6   19.6   25.5   26.5   19.2   26.2  ...
#
#    19시00분  19시30분  20시00분  20시30분  21시00분  21시30분  22시00분  22시30분  23시00분  \
# 0    20.0    15.1    11.1    12.0    12.5    10.1    10.4    16.4     7.8
# 1    37.5    26.5    25.5    26.4    26.3    21.1    32.1    20.3    12.6
# 2    24.1    17.4    13.7    14.5    15.8    12.1    14.5    18.3    11.7
# 3    33.8    22.9    22.0    24.1    23.0    21.0    24.8    18.5    11.8
# 4    28.8    20.2    19.1    18.7    22.2    16.1    21.8    25.1    16.3
#
#    23시30분
# 0     6.1
# 1    10.3
# 2    11.7
# 3     9.1
# 4    14.8
#
# ...

# %%
# 새로운 데이터프레임을 생성
new_station_division = pd.DataFrame()

# %%
# 구분
station_division = ['상선','하선','내선','외선']

# 역명별 평균값을 새로 생성한 데이터프레임에 추가
for j in station_division:
    select_data = data_station_division[data_station_division['구분']==j]
    new_data_seri = select_data.mean()
    new_station_division = new_station_division.append(new_data_seri, ignore_index=True)

# %%
new_station_division
# Out:
#        5시30분      6시00분      6시30분      7시00분      7시30분      8시00분  \
# 0  10.964664  11.178827  11.424464  14.003147  17.668956  23.911159
# 1  13.396423  13.328755  13.271674  16.046352  20.878112  28.342489
# 2  14.317647  12.771242  12.186275  15.047059  20.082353  31.752941
# 3  17.266013  13.971242  15.202614  18.521569  23.854902  33.667974
#
#        8시30분      9시00분      9시30분     10시00분  ...     19시00분     19시30분  \
# 0  21.713162  22.051359  20.564664  19.327468  ...  24.133619  19.671531
# 1  24.357082  23.720887  21.728040  19.972675  ...  21.464378  17.569528
# 2  27.855556  24.652288  22.175817  20.014379  ...  30.750327  24.657516
# 3  29.692157  28.952288  26.537908  24.211765  ...  29.389542  23.394771
#
#       20시00분     20시30분     21시00분     21시30분     22시00분     22시30분  \
# 0  18.127611  18.224034  18.771245  17.337482  18.632618  17.717454
# 1  16.204006  16.009156  16.774821  15.298569  16.647926  15.571245
# ...

# %%
# 데이터 행,열 변환
new_station_division = new_station_division.T

# %%
# 데이터 확인 [0 - 상선, 1 - 하선, 2 - 내선, 3 - 외선]
new_station_division
# Out:
#        5시30분      6시00분      6시30분      7시00분      7시30분      8시00분  \
# 0  10.964664  11.178827  11.424464  14.003147  17.668956  23.911159
# 1  13.396423  13.328755  13.271674  16.046352  20.878112  28.342489
# 2  14.317647  12.771242  12.186275  15.047059  20.082353  31.752941
# 3  17.266013  13.971242  15.202614  18.521569  23.854902  33.667974
#
#        8시30분      9시00분      9시30분     10시00분  ...     19시00분     19시30분  \
# 0  21.713162  22.051359  20.564664  19.327468  ...  24.133619  19.671531
# 1  24.357082  23.720887  21.728040  19.972675  ...  21.464378  17.569528
# 2  27.855556  24.652288  22.175817  20.014379  ...  30.750327  24.657516
# 3  29.692157  28.952288  26.537908  24.211765  ...  29.389542  23.394771
#
#       20시00분     20시30분     21시00분     21시30분     22시00분     22시30분  \
# 0  18.127611  18.224034  18.771245  17.337482  18.632618  17.717454
# 1  16.204006  16.009156  16.774821  15.298569  16.647926  15.571245
# ...

# %%
# 해당 요약 정보는 지하철 구분별 요약 정보입니다.
new_station_division.T.describe()
# Out:
#                0          1          2          3
# count  37.000000  37.000000  37.000000  37.000000
# mean   20.746754  20.315315  26.685020  26.796061
# std     5.400230   4.932371   7.102343   5.927001
# min    10.080830   9.125608  12.186275  13.971242
# 25%    18.127611  16.204006  22.175817  23.854902
# 50%    20.564664  20.878112  27.152288  27.358170
# 75%    23.161516  23.668526  31.507190  29.389542
# max    32.030758  29.172389  40.200654  39.126144

# %%
# 해당 요약 정보는 지하철 구분별 요약 정보입니다.
new_station_division.describe()
# Out:
#            5시30분      6시00분      6시30분      7시00분      7시30분      8시00분  \
# count   4.000000   4.000000   4.000000   4.000000   4.000000   4.000000
# mean   13.986187  12.812516  13.021257  15.904532  20.621081  29.418641
# std     2.604134   1.194403   1.639916   1.933866   2.551401   4.281598
# min    10.964664  11.178827  11.424464  14.003147  17.668956  23.911159
# 25%    12.788484  12.373138  11.995822  14.786081  19.479004  27.234657
# 50%    13.857035  13.049999  12.728974  15.546705  20.480232  30.047715
# 75%    15.054739  13.489377  13.754409  16.665156  21.622309  32.231699
# max    17.266013  13.971242  15.202614  18.521569  23.854902  33.667974
#
#            8시30분      9시00분      9시30분     10시00분  ...     19시00분     19시30분  \
# count   4.000000   4.000000   4.000000   4.000000  ...   4.000000   4.000000
# mean   25.904489  24.844205  22.751607  20.881572  ...  26.434467  21.323337
# std     3.564397   2.942505   2.613938   2.242286  ...   4.372444   3.277557
# ...

# %% [markdown]
# ### 3-2-1. 구분별 데이터 시각화

# %%
# 데이터 시각화
# seaborn 한글 깨짐 현상으로 폰트 적용
plt.rcParams['font.family'] = 'Malgun Gothic'

# 그래프 크기 설정
plt.rcParams["figure.figsize"] = (16,3)

plot = new_station_division.T.plot()
plot.set_xlabel("시간")
plot.set_ylabel("복잡도")
plt.title("구분별 복잡도")

# 오른쪽 상단 범례 표시
plt.legend(['상선','하선','내선','외선'], loc='upper right')
plt.show()

# %%
# 0 - 상선, 1 - 하선, 2 - 내선, 3 - 외선
#seaborn의 pairplot()을 사용해서 컬럼끼리 비교
sns.pairplot(new_station_division)

# %% [markdown]
# ## 3-3 요일별 데이터 분석

# %%
# 필요없는 컬럼 ['구분','호선','역명'] 제거
data_station_day = data_clean.drop(columns = ['구분','호선','역명'], axis = 1).copy()
data_station_day.head(3)
# Out:
#   조사일자  5시30분  6시00분  6시30분  7시00분  7시30분  8시00분  8시30분  9시00분  9시30분  ...  \
# 0   평일    6.2   14.6   13.4   26.8   43.3   53.6   70.9   40.4   38.0  ...
# 1   평일    9.1    8.6    9.3   15.2   29.3   27.7   19.0   18.5   15.1  ...
# 2   평일    5.4   10.1   13.0   20.8   32.0   40.6   50.9   30.8   35.8  ...
#
#    19시00분  19시30분  20시00분  20시30분  21시00분  21시30분  22시00분  22시30분  23시00분  \
# 0    20.0    15.1    11.1    12.0    12.5    10.1    10.4    16.4     7.8
# 1    37.5    26.5    25.5    26.4    26.3    21.1    32.1    20.3    12.6
# 2    24.1    17.4    13.7    14.5    15.8    12.1    14.5    18.3    11.7
#
#    23시30분
# 0     6.1
# 1    10.3
# 2    11.7
#
# [3 rows x 38 columns]

# %%
# 새로운 데이터프레임을 생성
new_station_day = pd.DataFrame()

# %%
# 구분명 리스트 생성
station_day = ['평일','토요일','일요일']

# 요일별 평균값을 새로 생성한 데이터프레임에 추가
for j in station_day:
    select_data = data_station_day[data_station_day['조사일자']==j]
    new_data_seri = select_data.mean()
    new_station_day = new_station_day.append(new_data_seri, ignore_index=True)

# %%
# 0 - 평일, 1 - 토요일, 2 - 일요일
new_station_day
# Out:
#        5시30분      6시00분      6시30분      7시00분      7시30분      8시00분  \
# 0  17.205634  17.012676  19.661268  27.954577  37.332746  50.833275
# 1  13.808099  13.079049  11.483099  11.444718  13.874824  19.637324
# 2   7.473415   7.271655   6.625176   6.622887   8.064965  11.456690
#
#        8시30분      9시00분      9시30분     10시00분  ...     19시00분     19시30분  \
# 0  40.260211  32.423239  25.970070  21.002465  ...  33.461268  24.660563
# 1  19.755458  22.883451  22.566901  22.360739  ...  21.364437  18.536796
# 2  12.181338  15.461444  16.631690  16.913908  ...  17.488380  15.576408
#
#       20시00분     20시30분     21시00분     21시30분     22시00분     22시30분  \
# 0  21.384331  20.541901  22.222007  21.476232  25.355634  24.429049
# 1  17.949472  18.791373  19.720599  18.052113  19.855810  18.521831
# 2  15.487500  15.745599  15.989613  13.922535  14.361268  12.830282
#
#       23시00분     23시30분
# 0  20.092958  13.864613
# 1  17.016373  12.068310
# 2  10.920423   7.047007
#
# ...

# %%
# 0 - 평일, 1 - 토요일, 2 - 일요일
# 조사일자별 요약
new_station_day.T.describe()
# Out:
#                0          1          2
# count  37.000000  37.000000  37.000000
# mean   26.627627  22.283317  16.027422
# std     8.756128   6.091233   5.028285
# min    13.864613  11.444718   6.622887
# 25%    21.002465  18.521831  12.830282
# 50%    22.968486  22.566901  16.783451
# 75%    30.286972  27.082570  20.261972
# max    50.833275  32.695246  22.658803

# %%
# 조사일자별 정제후 시간별 요약
new_station_day.describe()
# Out:
#            5시30분      6시00분      6시30분      7시00분      7시30분      8시00분  \
# count   3.000000   3.000000   3.000000   3.000000   3.000000   3.000000
# mean   12.829049  12.454460  12.589847  15.340728  19.757512  27.309096
# std     4.939425   4.900455   6.588140  11.186797  15.495331  20.779098
# min     7.473415   7.271655   6.625176   6.622887   8.064965  11.456690
# 25%    10.640757  10.175352   9.054137   9.033803  10.969894  15.547007
# 50%    13.808099  13.079049  11.483099  11.444718  13.874824  19.637324
# 75%    15.506866  15.045863  15.572183  19.699648  25.603785  35.235299
# max    17.205634  17.012676  19.661268  27.954577  37.332746  50.833275
#
#            8시30분      9시00분      9시30분     10시00분  ...     19시00분     19시30분  \
# count   3.000000   3.000000   3.000000   3.000000  ...   3.000000   3.000000
# mean   24.065669  23.589378  21.722887  20.092371  ...  24.104695  19.591256
# std    14.527189   8.502904   4.726056   2.835171  ...   8.331569   4.632967
# ...

# %% [markdown]
# ### 3-3-1. 데이터 시각화

# %%
# 데이터 시각화
# seaborn 한글 깨짐 현상으로 폰트 적용
plt.rcParams['font.family'] = 'Malgun Gothic'

# 그래프 크기 설정
plt.rcParams["figure.figsize"] = (16,3)

plot = new_station_day.T.plot()
plot.set_xlabel("시간")
plot.set_ylabel("복잡도")
plt.title("요일별 복잡도")

# 오른쪽 상단 범례 표시
plt.legend(['평일','토요일','일요일'], loc='upper right')
plt.show()

# %%
# 0 - 평일, 1 - 토요일, 2 - 일요일
#seaborn의 pairplot()을 사용해서 컬럼끼리 비교
sns.pairplot(new_station_day.T)

# %% [markdown]
# ## 3-4. 호선별 데이터 분석

# %%
# 필요없는 컬럼  ['구분','조사일자','역명'] 제거
data_station_num = data_clean.drop(columns = ['구분','조사일자','역명'], axis = 1).copy()
data_station_num.head(3)
# Out:
#    호선  5시30분  6시00분  6시30분  7시00분  7시30분  8시00분  8시30분  9시00분  9시30분  ...  \
# 0   1    6.2   14.6   13.4   26.8   43.3   53.6   70.9   40.4   38.0  ...
# 1   1    9.1    8.6    9.3   15.2   29.3   27.7   19.0   18.5   15.1  ...
# 2   1    5.4   10.1   13.0   20.8   32.0   40.6   50.9   30.8   35.8  ...
#
#    19시00분  19시30분  20시00분  20시30분  21시00분  21시30분  22시00분  22시30분  23시00분  \
# 0    20.0    15.1    11.1    12.0    12.5    10.1    10.4    16.4     7.8
# 1    37.5    26.5    25.5    26.4    26.3    21.1    32.1    20.3    12.6
# 2    24.1    17.4    13.7    14.5    15.8    12.1    14.5    18.3    11.7
#
#    23시30분
# 0     6.1
# 1    10.3
# 2    11.7
#
# [3 rows x 38 columns]

# %%
# 새로운 데이터프레임을 생성
new_station_num = pd.DataFrame()

# %%
# 인덱스 길이
index_len = len(data_station_num.index)

# 호선 데이터 저장을 위한 set 생성
station_num = set([])

# 호선 추출
for i in range(index_len):
    station_num.add(data_station_num['호선'][i])

# 역명별 평균값을 새로 생성한 데이터프레임에 추가
for j in station_num:
    station_len = len(data_station_num[data_station_num['호선']==j])
    select_data = data_station_num[data_station_num['호선']==j]
    new_data_seri = select_data.mean()
    new_station_num = new_station_num.append(new_data_seri, ignore_index=True)

# %%
new_station_num
# Out:
#       호선      5시30분      6시00분      6시30분      7시00분      7시30분      8시00분  \
# 0    1.0   7.076667   8.695000   8.446667  10.998333  15.588333  20.673333
# 1    2.0  17.536047  14.455039  14.562016  18.126357  23.474031  35.320155
# 2    3.0   9.305882  11.130882  10.947059  14.123039  19.061765  26.676471
# 3    4.0  14.921795  14.140385  13.216667  15.723718  19.961538  29.401923
# 4    5.0  10.965646  11.085714  11.735034  15.259524  19.353401  25.434354
# 5    6.0   7.167094   7.432906   7.650000   9.982906  13.100000  18.582479
# 6    7.0  19.643137  18.550654  17.779739  20.353595  24.921569  31.309804
# 7    8.0  11.424510  10.596078  13.066667  14.442157  19.205882  27.767647
# 8   13.0   4.250000   4.895833   6.066667   6.237500   8.420833  13.233333
# 9   14.0   8.583333  10.195833  11.995833  12.904167  19.333333  24.133333
# 10  15.0   7.154762   8.969048  10.647619  11.597619  15.861905  24.216667
#
# ...

# %%
# 시간별 데이터 통계정보 확인
new_station_num.describe()
# Out:
#               호선      5시30분      6시00분      6시30분      7시00분      7시30분  \
# count  11.000000  11.000000  11.000000  11.000000  11.000000  11.000000
# mean    7.090909  10.729898  10.922488  11.464906  13.613538  18.025690
# std     4.908249   4.809631   3.728307   3.304523   3.910193   4.626689
# min     1.000000   4.250000   4.895833   6.066667   6.237500   8.420833
# 25%     3.500000   7.160928   8.832024   9.547143  11.297976  15.725119
# 50%     6.000000   9.305882  10.596078  11.735034  14.123039  19.205882
# 75%    10.500000  13.173152  12.635633  13.141667  15.491621  19.657470
# max    15.000000  19.643137  18.550654  17.779739  20.353595  24.921569
#
#            8시00분      8시30분      9시00분      9시30분  ...     19시00분     19시30분  \
# count  11.000000  11.000000  11.000000  11.000000  ...  11.000000  11.000000
# mean   25.159045  22.052316  21.140463  19.580023  ...  21.217292  17.095866
# std     6.130259   5.476415   5.987441   5.321323  ...   6.619318   5.535216
# ...

# %%
# 호선별 통계정보 확인
new_station_num.T.describe()
# Out:
#               0          1          2          3          4          5   \
# count  38.000000  38.000000  38.000000  38.000000  38.000000  38.000000
# mean   18.463947  28.953172  21.136507  23.038394  19.281919  15.026709
# std     6.914089   8.386600   6.791892   5.921998   5.592312   4.437946
# min     1.000000   2.000000   3.000000   4.000000   5.000000   6.000000
# 25%    13.821667  25.862694  17.811029  20.397436  16.045663  13.058654
# 50%    18.962500  29.651744  22.358578  23.781731  19.867687  14.895940
# 75%    24.287500  33.741085  24.998162  26.132212  22.243963  17.333974
# max    30.676667  43.975581  32.357353  34.244872  28.832653  24.002991
#
#               6          7          8          9          10
# count  38.000000  38.000000  38.000000  38.000000  38.000000
# mean   23.762315  19.710139   8.530592  13.468860  15.969236
# std     5.863703   6.019334   3.129748   3.851031   4.400071
# min     7.000000   8.000000   1.683333   5.241667   6.238095
# ...

# %% [markdown]
# ## 3-4-1. 데이터 시각화

# %%
# 데이터 시각화
# seaborn 한글 깨짐 현상으로 폰트 적용
plt.rcParams['font.family'] = 'Malgun Gothic'
plt.figure(figsize=(12, 3))

plt.rcParams["figure.figsize"] = (16,8)

plot = new_station_num.T.plot()
plot.set_xlabel("시간")
plot.set_ylabel("복잡도")
plt.title("호선별 복잡도")

plt.legend(['1호선','2호선','3호선','4호선','5호선','6호선','7호선','8호선','13호선','14호선','15호선'], loc='upper right')
plt.show()

# %%
# 0 - 평일, 1 - 토요일, 2 - 일요일
#seaborn의 pairplot()을 사용해서 컬럼끼리 비교
sns.pairplot(new_station_num.T)

# %% [markdown]
# ## 3-5. 시간별 데이터 분석

# %%
# 필요없는 컬럼 ['조사일자','구분','호선','역명'] 제거
data_station_time = data_clean.drop(columns = ['조사일자','구분','호선','역명'], axis = 1).copy()
data_station_time.head(3)
# Out:
#    5시30분  6시00분  6시30분  7시00분  7시30분  8시00분  8시30분  9시00분  9시30분  10시00분  ...  \
# 0    6.2   14.6   13.4   26.8   43.3   53.6   70.9   40.4   38.0    26.6  ...
# 1    9.1    8.6    9.3   15.2   29.3   27.7   19.0   18.5   15.1    13.9  ...
# 2    5.4   10.1   13.0   20.8   32.0   40.6   50.9   30.8   35.8    20.2  ...
#
#    19시00분  19시30분  20시00분  20시30분  21시00분  21시30분  22시00분  22시30분  23시00분  \
# 0    20.0    15.1    11.1    12.0    12.5    10.1    10.4    16.4     7.8
# 1    37.5    26.5    25.5    26.4    26.3    21.1    32.1    20.3    12.6
# 2    24.1    17.4    13.7    14.5    15.8    12.1    14.5    18.3    11.7
#
#    23시30분
# 0     6.1
# 1    10.3
# 2    11.7
#
# [3 rows x 37 columns]

# %%
# 시간별 요약 확인
data_station_time.describe()
# Out:
#              5시30분        6시00분        6시30분        7시00분        7시30분  \
# count  1704.000000  1704.000000  1704.000000  1704.000000  1704.000000
# mean     12.829049    12.454460    12.589847    15.340728    19.757512
# std      11.507665     8.893017    10.275193    14.774740    19.332359
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       5.600000     6.500000     5.875000     6.275000     7.300000
# 50%       9.700000    10.300000     9.700000    10.150000    12.650000
# 75%      16.500000    16.100000    15.925000    18.500000    24.800000
# max      89.000000    56.500000    66.800000    93.400000   107.900000
#
#              8시00분        8시30분        9시00분        9시30분       10시00분  ...  \
# count  1704.000000  1704.000000  1704.000000  1704.000000  1704.000000  ...
# mean     27.309096    24.065669    23.589378    21.722887    20.092371  ...
# std      26.940089    22.153565    18.195431    13.804853    11.458290  ...
# ...

# %%
# 데이터 시각화 - 시간별 평균 복잡도
# seaborn 한글 깨짐 현상으로 폰트 적용
plt.rcParams['font.family'] = 'Malgun Gothic'
plt.figure(figsize=(12, 3))

plt.rcParams["figure.figsize"] = (16,8)

plot = data_station_time.mean().plot()
plot.set_xlabel("시간")
plot.set_ylabel("복잡도")
plt.title("시간별 복잡도")

plt.legend(['시간별 평균 복잡도'], loc='upper right')
plt.show()

# %% [markdown]
# 시간별 평균 데이터를 보게되면, 출퇴근시간의 복잡도가 높게 나오지만, 좌석기준 '34%' 이내의 복잡도를 보여주고 있다. 이는, 다른 조건을 생각하지 않고, 평균 데이터를 그래프로 보여주고 있어 나온 현상이라 판단된다.

# %% [markdown]
# ## 4. '8시30분'과 상관관계 확인

# %%
# '8시30분'과 상관관계를 내림차순으로 어떤 feature가 상관관계가 강한지 확인
check_data = data.copy()
# replace를 사용하여, 수치형 데이터 변환
check_data = check_data.replace({'상선': 0, '하선': 1, '내선' : 2, '외선' : 3, '평일' : 0, '토요일' : 1, '일요일' : 2})
check_data.corr()[['8시30분']].sort_values(by="8시30분", ascending=False).style.background_gradient()
# Out:
# <style type="text/css">
# #T_d92a9_row0_col0 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_d92a9_row1_col0 {
#   background-color: #023f64;
#   color: #f1f1f1;
# }
# #T_d92a9_row2_col0 {
#   background-color: #034267;
#   color: #f1f1f1;
# }
# #T_d92a9_row3_col0, #T_d92a9_row4_col0 {
#   background-color: #034369;
#   color: #f1f1f1;
# }
# #T_d92a9_row5_col0 {
#   background-color: #034a74;
#   color: #f1f1f1;
# }
# #T_d92a9_row6_col0 {
#   background-color: #034d79;
#   color: #f1f1f1;
# }
# #T_d92a9_row7_col0 {
#   background-color: #045e93;
#   color: #f1f1f1;
# }
# #T_d92a9_row8_col0 {
#   background-color: #046096;
#   color: #f1f1f1;
# }
# #T_d92a9_row9_col0 {
#   background-color: #04649d;
#   color: #f1f1f1;
# }
# #T_d92a9_row10_col0 {
#   background-color: #0566a0;
#   color: #f1f1f1;
# }
# #T_d92a9_row11_col0 {
#   background-color: #056ba9;
#   color: #f1f1f1;
# }
# #T_d92a9_row12_col0, #T_d92a9_row13_col0 {
#   background-color: #1077b4;
# ...

# %% [markdown]
# 위의 상관관계를 보면, '구분','역번호','조사일자','호선'의 상관관계는 강하지가 않은것을 보이며, 30분전후의 데이터의 경우 강한 상관관계인것을 확인할 수 있었다. 따라서, '8시30분'의 데이터를 추측하기 위한 학습에 '8시00분','9시00분'의 데이터도 추가적으로 필요할 것으로 판단했다.

# %%
# '8시00분','9시00분'으로 '8시30분' 복잡도 확인해 보기
X_8_9 = data[['9시00분','8시00분']]
X_8_9 = X_8_9.to_numpy()
y = data['8시30분']
y = y.to_numpy().reshape(-1,1)

# %%
# 시각화
plt.scatter(X_8_9[:,0], X_8_9[:,1], c=y)
plt.xlabel('8시00분')
plt.ylabel('9시00분')
plt.title('8시30분 Distrubtion')
plt.show()

# %% [markdown]
# ## 5. 데이터 전처리
# - 위의 분석 중 시간별 데이터를 기준으로 전처리 및 학습을 진행해보기로 하였습니다.

# %%
# 위에서 정재한 시간별 데이터값 확인
data_station_time.head()
# Out:
#    5시30분  6시00분  6시30분  7시00분  7시30분  8시00분  8시30분  9시00분  9시30분  10시00분  ...  \
# 0    6.2   14.6   13.4   26.8   43.3   53.6   70.9   40.4   38.0    26.6  ...
# 1    9.1    8.6    9.3   15.2   29.3   27.7   19.0   18.5   15.1    13.9  ...
# 2    5.4   10.1   13.0   20.8   32.0   40.6   50.9   30.8   35.8    20.2  ...
# 3    7.0    6.8   10.2   14.5   27.0   24.7   20.0   18.4   14.5    13.5  ...
# 4    5.2   10.8    9.3   13.6   19.6   25.5   26.5   19.2   26.2    17.0  ...
#
#    19시00분  19시30분  20시00분  20시30분  21시00분  21시30분  22시00분  22시30분  23시00분  \
# 0    20.0    15.1    11.1    12.0    12.5    10.1    10.4    16.4     7.8
# 1    37.5    26.5    25.5    26.4    26.3    21.1    32.1    20.3    12.6
# 2    24.1    17.4    13.7    14.5    15.8    12.1    14.5    18.3    11.7
# 3    33.8    22.9    22.0    24.1    23.0    21.0    24.8    18.5    11.8
# 4    28.8    20.2    19.1    18.7    22.2    16.1    21.8    25.1    16.3
#
#    23시30분
# 0     6.1
# 1    10.3
# 2    11.7
# ...

# %%
# 예측해야 할 변수인 `Risk`를 제거하여 머신러닝 입력값인 x에 저장합니다.
x = data_station_time.drop(columns = ['8시30분']).to_numpy()

# %%
# 예측해야 할 변수 `Risk`만을 선택하여 numpy 형태로 y에 저장합니다.
y = data_station_time['8시30분']
# y = y.to_numpy().ravel() # 1 차원 벡터 형태로 출력하기 위해 ravel 사용

# %%
y
# Out:
# 0       70.9
# 1       19.0
# 2       50.9
# 3       20.0
# 4       26.5
#         ...
# 1699     3.7
# 1700     3.1
# 1701     4.5
# 1702     2.1
# 1703     0.0
# Name: 8시30분, Length: 1704, dtype: float64

# %% [markdown]
# ### 5-1. 학습, 테스트 데이터 분리

# %%
# sklearn에서 제공하는 train_test_split 사용을 위해 임포트
from sklearn.model_selection import train_test_split

# %%
# 예측해야 할 변수인 `8시30분`을 제거하여 머신러닝 입력값인 x에 저장합니다.
X = data.drop(columns = ['8시30분'])
# 특성 데이터 선정
X = data[['8시00분','9시00분','구분','호선','조사일자']]
X.shape
# Out:
# (1704, 5)

# %%
X
# Out:
#       8시00분  9시00분  구분  호선 조사일자
# 0      53.6   40.4  상선   1   평일
# 1      27.7   18.5  하선   1   평일
# 2      40.6   30.8  상선   1   평일
# 3      24.7   18.4  하선   1   평일
# 4      25.5   19.2  상선   1   평일
# ...     ...    ...  ..  ..  ...
# 1699    3.7    5.4  하선   8  일요일
# 1700    2.7    3.8  상선   8  일요일
# 1701    4.3    5.5  하선   8  일요일
# 1702    1.6    2.8  상선   8  일요일
# 1703    0.0    0.0  하선   8  일요일
#
# [1704 rows x 5 columns]

# %%
# 훈련을 위해 replace를 사용하여, 수치형 데이터 변환
X = X.replace({'상선': 0, '하선': 1, '내선' : 2, '외선' : 3, '평일' : 0, '토요일' : 1, '일요일' : 2})

# %%
# 변환후 데이터 확인
X
# Out:
#       8시00분  9시00분  구분  호선  조사일자
# 0      53.6   40.4   0   1     0
# 1      27.7   18.5   1   1     0
# 2      40.6   30.8   0   1     0
# 3      24.7   18.4   1   1     0
# 4      25.5   19.2   0   1     0
# ...     ...    ...  ..  ..   ...
# 1699    3.7    5.4   1   8     2
# 1700    2.7    3.8   0   8     2
# 1701    4.3    5.5   1   8     2
# 1702    1.6    2.8   0   8     2
# 1703    0.0    0.0   1   8     2
#
# [1704 rows x 5 columns]

# %%
# 분류할 데이터
y = data['8시30분']
# 분류할 데이터 갯수 확인
y.value_counts()
# Out:
# 0.0     45
# 12.1    16
# 14.5    12
# 16.6    12
# 8.1     12
#         ..
# 64.4     1
# 61.6     1
# 70.1     1
# 76.0     1
# 4.4      1
# Name: 8시30분, Length: 573, dtype: int64

# %%
# sklearn에서 제공하는 train_test_split을 사용하여 데이터분리
X_train, X_valid, y_train, y_valid = train_test_split(X, y, test_size=0.3, random_state = 0)

# %%
# 분리된 X_train 확인
X_train
# Out:
#       8시00분  9시00분  구분  호선  조사일자
# 1260    5.4   10.3   0   3     2
# 572    13.9   15.7   0   1     1
# 1211   30.4   39.9   3   2     2
# 1565    0.9    1.0   1   6     2
# 1267   19.3   22.4   1   3     2
# ...     ...    ...  ..  ..   ...
# 835    34.9   40.0   1   5     1
# 1216   14.7   18.6   2   2     2
# 1653   10.4   16.2   1   7     2
# 559    17.9    8.2   1   8     0
# 684     6.8   10.4   2  14     1
#
# [1192 rows x 5 columns]

# %% [markdown]
# ## 6. 학습

# %%
# 모델 생성
model = Sequential([
    Input(shape=(5, )),
    Dense(32, activation='relu'),
    BatchNormalization(),
    Dense(64, activation='relu'),
    BatchNormalization(),
    Dense(32, activation='relu'),
    BatchNormalization(),
    Dense(num_class, activation='softmax')
])

model.summary()
# Out:
# Model: "sequential_49"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_188 (Dense)           (None, 32)                192
#
#  batch_normalization_139 (Ba  (None, 32)               128
#  tchNormalization)
#
#  dense_189 (Dense)           (None, 64)                2112
#
#  batch_normalization_140 (Ba  (None, 64)               256
#  tchNormalization)
#
#  dense_190 (Dense)           (None, 32)                2080
#
#  batch_normalization_141 (Ba  (None, 32)               128
#  tchNormalization)
#
#  dense_191 (Dense)           (None, 573)               18909
#
# ...
# Total params: 23,805
# Trainable params: 23,549
# Non-trainable params: 256
# _________________________________________________________________

# %%
# 모델 컴파일
model.compile(
    optimizer=Adam(learning_rate=0.001),
    loss='sparse_categorical_crossentropy',
    metrics=['acc']
)

# %%
# 모델 훈련
history = model.fit(
    X_train,
    y_train,
    validation_data=(X_valid, y_valid),
    epochs=2000,
    batch_size=batch_size,
)
# Out:
# Epoch 1/2000
# 19/19 [==============================] - 1s 11ms/step - loss: 6.2921 - acc: 0.0017 - val_loss: 6.3986 - val_acc: 0.0000e+00
# Epoch 2/2000
# 19/19 [==============================] - 0s 5ms/step - loss: 6.0096 - acc: 0.0268 - val_loss: 6.3004 - val_acc: 0.0020
# Epoch 3/2000
# 19/19 [==============================] - 0s 5ms/step - loss: 5.7145 - acc: 0.0352 - val_loss: 6.1638 - val_acc: 0.0234
# Epoch 4/2000
# 19/19 [==============================] - 0s 5ms/step - loss: 5.3684 - acc: 0.0336 - val_loss: 5.9348 - val_acc: 0.0293
# Epoch 5/2000
# 19/19 [==============================] - 0s 5ms/step - loss: 4.9707 - acc: 0.0352 - val_loss: 5.5935 - val_acc: 0.0332
# Epoch 6/2000
# 19/19 [==============================] - 0s 5ms/step - loss: 4.5513 - acc: 0.0344 - val_loss: 5.1389 - val_acc: 0.0352
# Epoch 7/2000
# 19/19 [==============================] - 0s 5ms/step - loss: 4.1275 - acc: 0.0344 - val_loss: 4.6541 - val_acc: 0.0352
# Epoch 8/2000
# ...

# %%
# Epoch 2000번 설정 후 훈련했을경우
plt.figure(figsize=(20, 10))

train_loss = history.history["loss"]
valid_loss = history.history["val_loss"]

plt.plot(train_loss, label="train loss")
plt.plot(valid_loss, label="valid loss")

plt.legend()
plt.show()

# %%
# Epoch 2000번 설정 후 훈련했을경우
plt.figure(figsize=(20, 10))

train_loss = history.history["acc"]
valid_loss = history.history["val_acc"]

plt.plot(train_loss, label="train accuracy")
plt.plot(valid_loss, label="valid accuracy")

plt.legend()

plt.show()

# %%
# Epoch 100번 설정 후 훈련했을경우
plt.figure(figsize=(20, 10))

train_loss = history.history["loss"]
valid_loss = history.history["val_loss"]

plt.plot(train_loss, label="train loss")
plt.plot(valid_loss, label="valid loss")

plt.legend()
plt.show()

# %%
# Epoch 100번 설정 후 훈련했을경우
plt.figure(figsize=(20, 10))

train_loss = history.history["acc"]
valid_loss = history.history["val_acc"]

plt.plot(train_loss, label="train accuracy")
plt.plot(valid_loss, label="valid accuracy")

plt.legend()

plt.show()

# %% [markdown]
# ## 7. 발전 가능성

# %% [markdown]
# 역별,구분별,요일별,호선별,시간별 데이터를 요약과 시각화를 통해 분석을 해보고, '8시30분'을 추측할 수 있도록 모델 생성 및 훈련을 해보았다. 아쉽게도 훈련의 결과는 상단 그래프를 보면 알겠지만, 훈련 횟수가 높아질수록 'vaild_loss'가 낮아지는것이 아니라, 높아지는것을 확인할 수 있었다. 이는 분류할 클래스가 한쪽에 데이터가 너무 많이 있어 발생한 현상으로 보여, 전처리가 더 필요할 것으로 판단을 한다. 이러한 훈련을 통해 복잡도가 높은 시간에 압사에 대한 위험을 경고해줄 수 있는 시스템과 우회경로를 안내해줄수 있지 않을까 기대를 한다.
